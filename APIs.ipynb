# %% [markdown]
# # Consultando APIs

# %% [markdown]
# ## Instale a biblioteca de requests, caso ainda não tenha

# %%
# !pip install requests    
# ou
# !conda install requests

# %% [markdown]
# ## Importe as bibliotecas

# %%
import pandas as pd
import numpy as np
import csv
import requests

# %% [markdown]
# ## Declare a url

# %%
url = "http://api.open-notify.org/astros.json"

# %% [markdown]
# ## Faça um request utlizando requests.get()

# %%
api = requests.get(url)

# %% [markdown]
# ## Veja o código de status

# %%
print(api.status_code)
# Out:
# 200

# %%
# O código 200 significa está tudo ok

# %%
# Para saber mais:
# https://httpstatuses.com/

# %% [markdown]
# ## Imprima o texto

# %%
print(api.text)
# Out:
# {"people": [{"craft": "ISS", "name": "Andrew Morgan"}, {"craft": "ISS", "name": "Oleg Skripochka"}, {"craft": "ISS", "name": "Jessica Meir"}], "message": "success", "number": 3}

# %% [markdown]
# ## Retorne os dados como um json

# %%
json = api.json()

# %%
json
# Out:
# {'people': [{'craft': 'ISS', 'name': 'Andrew Morgan'},
#   {'craft': 'ISS', 'name': 'Oleg Skripochka'},
#   {'craft': 'ISS', 'name': 'Jessica Meir'}],
#  'message': 'success',
#  'number': 3}

# %% [markdown]
# ## Crie um dataframe

# %%
df = pd.DataFrame(json)

# %%
df.head()
# Out:
#                                         people  message  number
# 0    {'craft': 'ISS', 'name': 'Andrew Morgan'}  success       3
# 1  {'craft': 'ISS', 'name': 'Oleg Skripochka'}  success       3
# 2     {'craft': 'ISS', 'name': 'Jessica Meir'}  success       3

# %% [markdown]
# ## Exemplo caso coinmarket (dado em aula, não havia necessidade de inserir key)

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
api = requests.get(url)
json = api.json()
json
# Out:
# {'status': {'timestamp': '2020-03-12T14:59:52.853Z',
#   'error_code': 1002,
#   'error_message': 'API key missing.',
#   'elapsed': 0,
#   'credit_count': 0}}

# %% [markdown]
#  O site retornou uma mensagem de erro, indicando que é necessário inserir a chave

# %% [markdown]
# ## Exemplo coinmarket : segundo documentação

# %%
# Consultando a documentação do site, seguirei as instruções:
# https://coinmarketcap.com/api/documentation/v1/#operation/getV1GlobalmetricsQuotesLatest

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
key = 'xxxx'#necessário se cadastrar no site para obter a chave

# %%
parameters={'convert':'USD'}
headers={'Accepts':'application/json', 'X-CMC_PRO_API_KEY':key}

# %%
session=Session()
session.headers.update(headers)

# %%
try:
    response =session.get(url, params=parameters)
    data=json.loads(response.text)
    print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# {'status': {'timestamp': '2020-03-12T14:59:53.168Z', 'error_code': 0, 'error_message': None, 'elapsed': 24, 'credit_count': 1, 'notice': None}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 7785, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18266962, 'total_supply': 18266962, 'platform': None, 'cmc_rank': 1, 'last_updated': '2020-03-12T14:58:17.000Z', 'quote': {'USD': {'price': 6108.06910811, 'volume_24h': 52562319536.7263, 'percent_change_1h': 2.75374, 'percent_change_24h': -22.0853, 'percent_change_7d': -32.8301, 'market_cap': 111575866291.21927, 'last_updated': '2020-03-12T14:58:17.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5180, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': None, 'circulating_supply': 110065601.9365, 'total_supply': 110065601.9365, 'platform': None, 'cmc_rank': 2, 'last_updated': '2020-03-12T14:59:26.000Z', 'quote': {'USD': {'price': 140.3567941, 'volume_24h': 22241726275.7532, 'percent_change_1h': 4.82718, 'percent_change_24h': -28.3034, 'percent_change_7d': -39.5191, 'market_cap': 15448455028.49389, 'last_updated': '2020-03-12T14:59:26.000Z'}}}, {'id': 52, 'name': 'XRP', 'symbol': 'XRP', 'slug': 'xrp', 'num_market_pairs': 505, 'date_added': '2013-08-04T00:00:00.000Z', 'tags': [], 'max_supply': 100000000000, 'circulating_supply': 43818008717, 'total_supply': 99991068479, 'platform': None, 'cmc_rank': 3, 'last_updated': '2020-03-12T14:59:03.000Z', 'quote': {'USD': {'price': 0.165223525359, 'volume_24h': 3251281746.08163, 'percent_change_1h': 4.43558, 'percent_change_24h': -20.3332, 'percent_change_7d': -31.3598, 'market_cap': 7239765874.434133, 'last_updated': '2020-03-12T14:59:03.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 4229, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': [], 'max_supply': None, 'circulating_supply': 4642367414, 'total_supply': 4776930644, 'platform': {'id': 83, 'name': 'Omni', 'symbol': 'OMNI', 'slug': 'omni', 'token_address': '31'}, 'cmc_rank': 4, 'last_updated': '2020-03-12T14:59:23.000Z', 'quote': {'USD': {'price': 1.00339679251, 'volume_24h': 69295805726.9652, 'percent_change_1h': 0.36201, 'percent_change_24h': 0.0692116, 'percent_change_7d': 0.0823717, 'market_cap': 4658136572.860543, 'last_updated': '2020-03-12T14:59:23.000Z'}}}, {'id': 1831, 'name': 'Bitcoin Cash', 'symbol': 'BCH', 'slug': 'bitcoin-cash', 'num_market_pairs': 457, 'date_added': '2017-07-23T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18326337.5, 'total_supply': 18326337.5, 'platform': None, 'cmc_rank': 5, 'last_updated': '2020-03-12T14:59:06.000Z', 'quote': {'USD': {'price': 180.953362941, 'volume_24h': 5079150103.36312, 'percent_change_1h': 4.63508, 'percent_change_24h': -31.062, 'percent_change_7d': -46.692, 'market_cap': 3316212401.0167584, 'last_updated': '2020-03-12T14:59:06.000Z'}}}, {'id': 2, 'name': 'Litecoin', 'symbol': 'LTC', 'slug': 'litecoin', 'num_market_pairs': 568, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 84000000, 'circulating_supply': 64275974.6287857, 'total_supply': 64275974.6287857, 'platform': None, 'cmc_rank': 6, 'last_updated': '2020-03-12T14:59:06.000Z', 'quote': {'USD': {'price': 34.7926318983, 'volume_24h': 4962298425.01185, 'percent_change_1h': 7.9608, 'percent_change_24h': -27.8864, 'percent_change_7d': -44.2748, 'market_cap': 2236330325.1638107, 'last_updated': '2020-03-12T14:59:06.000Z'}}}, {'id': 3602, 'name': 'Bitcoin SV', 'symbol': 'BSV', 'slug': 'bitcoin-sv', 'num_market_pairs': 170, 'date_added': '2018-11-09T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18324039.5819233, 'total_supply': 18324039.5819233, 'platform': None, 'cmc_rank': 7, 'last_updated': '2020-03-12T14:59:13.000Z', 'quote': {'USD': {'price': 120.905 ...

# %%
# Qual o tipo de dado que API retornou?

# %%
type(data)
# Out:
# dict

# %%
# A API retornou um dicionário

# %%
# Quais são as chaves do dicionário data?

# %%
data.keys()
# Out:
# dict_keys(['status', 'data'])

# %%
type(data['status'])
# Out:
# dict

# %%
# Os dados dentro da chave 'status' estão no formato de dicionário

# %%
type(data['data'])
# Out:
# list

# %%
# Os dados dentro da chave 'data' estão no formato de lista

# %%
len(data['data'])
# Out:
# 100

# %%
print(data['data'])
# Out:
# [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 7785, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18266962, 'total_supply': 18266962, 'platform': None, 'cmc_rank': 1, 'last_updated': '2020-03-12T14:58:17.000Z', 'quote': {'USD': {'price': 6108.06910811, 'volume_24h': 52562319536.7263, 'percent_change_1h': 2.75374, 'percent_change_24h': -22.0853, 'percent_change_7d': -32.8301, 'market_cap': 111575866291.21927, 'last_updated': '2020-03-12T14:58:17.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5180, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': None, 'circulating_supply': 110065601.9365, 'total_supply': 110065601.9365, 'platform': None, 'cmc_rank': 2, 'last_updated': '2020-03-12T14:59:26.000Z', 'quote': {'USD': {'price': 140.3567941, 'volume_24h': 22241726275.7532, 'percent_change_1h': 4.82718, 'percent_change_24h': -28.3034, 'percent_change_7d': -39.5191, 'market_cap': 15448455028.49389, 'last_updated': '2020-03-12T14:59:26.000Z'}}}, {'id': 52, 'name': 'XRP', 'symbol': 'XRP', 'slug': 'xrp', 'num_market_pairs': 505, 'date_added': '2013-08-04T00:00:00.000Z', 'tags': [], 'max_supply': 100000000000, 'circulating_supply': 43818008717, 'total_supply': 99991068479, 'platform': None, 'cmc_rank': 3, 'last_updated': '2020-03-12T14:59:03.000Z', 'quote': {'USD': {'price': 0.165223525359, 'volume_24h': 3251281746.08163, 'percent_change_1h': 4.43558, 'percent_change_24h': -20.3332, 'percent_change_7d': -31.3598, 'market_cap': 7239765874.434133, 'last_updated': '2020-03-12T14:59:03.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 4229, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': [], 'max_supply': None, 'circulating_supply': 4642367414, 'total_supply': 4776930644, 'platform': {'id': 83, 'name': 'Omni', 'symbol': 'OMNI', 'slug': 'omni', 'token_address': '31'}, 'cmc_rank': 4, 'last_updated': '2020-03-12T14:59:23.000Z', 'quote': {'USD': {'price': 1.00339679251, 'volume_24h': 69295805726.9652, 'percent_change_1h': 0.36201, 'percent_change_24h': 0.0692116, 'percent_change_7d': 0.0823717, 'market_cap': 4658136572.860543, 'last_updated': '2020-03-12T14:59:23.000Z'}}}, {'id': 1831, 'name': 'Bitcoin Cash', 'symbol': 'BCH', 'slug': 'bitcoin-cash', 'num_market_pairs': 457, 'date_added': '2017-07-23T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18326337.5, 'total_supply': 18326337.5, 'platform': None, 'cmc_rank': 5, 'last_updated': '2020-03-12T14:59:06.000Z', 'quote': {'USD': {'price': 180.953362941, 'volume_24h': 5079150103.36312, 'percent_change_1h': 4.63508, 'percent_change_24h': -31.062, 'percent_change_7d': -46.692, 'market_cap': 3316212401.0167584, 'last_updated': '2020-03-12T14:59:06.000Z'}}}, {'id': 2, 'name': 'Litecoin', 'symbol': 'LTC', 'slug': 'litecoin', 'num_market_pairs': 568, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 84000000, 'circulating_supply': 64275974.6287857, 'total_supply': 64275974.6287857, 'platform': None, 'cmc_rank': 6, 'last_updated': '2020-03-12T14:59:06.000Z', 'quote': {'USD': {'price': 34.7926318983, 'volume_24h': 4962298425.01185, 'percent_change_1h': 7.9608, 'percent_change_24h': -27.8864, 'percent_change_7d': -44.2748, 'market_cap': 2236330325.1638107, 'last_updated': '2020-03-12T14:59:06.000Z'}}}, {'id': 3602, 'name': 'Bitcoin SV', 'symbol': 'BSV', 'slug': 'bitcoin-sv', 'num_market_pairs': 170, 'date_added': '2018-11-09T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18324039.5819233, 'total_supply': 18324039.5819233, 'platform': None, 'cmc_rank': 7, 'last_updated': '2020-03-12T14:59:13.000Z', 'quote': {'USD': {'price': 120.905934001, 'volume_24h': 2271521983.30787, 'percent_change_1h': 5.5847, 'percent_change_24h': -36.98, 'percent_change_7d': -50.2986, 'market_cap': 22154851 ...

# %%
print(data['data'][0])
# Out:
# {'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 7785, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18266962, 'total_supply': 18266962, 'platform': None, 'cmc_rank': 1, 'last_updated': '2020-03-12T14:58:17.000Z', 'quote': {'USD': {'price': 6108.06910811, 'volume_24h': 52562319536.7263, 'percent_change_1h': 2.75374, 'percent_change_24h': -22.0853, 'percent_change_7d': -32.8301, 'market_cap': 111575866291.21927, 'last_updated': '2020-03-12T14:58:17.000Z'}}}

# %% [markdown]
# ### Transformação dos dados em um DataFrame

# %%
df = pd.DataFrame(data['data'])

# %%
df.shape
# Out:
# (100, 14)

# %%
pd.set_option('display.max_rows',15)

# %%
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              7785
# 1  1027      Ethereum    ETH      ethereum              5180
# 2    52           XRP    XRP           xrp               505
# 3   825        Tether   USDT        tether              4229
# 4  1831  Bitcoin Cash    BCH  bitcoin-cash               457
#
#                  date_added        tags    max_supply  circulating_supply  \
# 0  2013-04-28T00:00:00.000Z  [mineable]  2.100000e+07        1.826696e+07
# 1  2015-08-07T00:00:00.000Z  [mineable]           NaN        1.100656e+08
# 2  2013-08-04T00:00:00.000Z          []  1.000000e+11        4.381801e+10
# 3  2015-02-25T00:00:00.000Z          []           NaN        4.642367e+09
# 4  2017-07-23T00:00:00.000Z  [mineable]  2.100000e+07        1.832634e+07
#
#    total_supply                                           platform  cmc_rank  \
# 0  1.826696e+07                                               None         1
# 1  1.100656e+08                                               None         2
# 2  9.999107e+10                                               None         3
# 3  4.776931e+09  {'id': 83, 'name': 'Omni', 'symbol': 'OMNI', '...         4
# 4  1.832634e+07                                               None         5
#
#                last_updated                                              quote
# 0  2020-03-12T14:58:17.000Z  {'USD': {'price': 6108.06910811, 'volume_24h':...
# 1  2020-03-12T14:59:26.000Z  {'USD': {'price': 140.3567941, 'volume_24h': 2...
# 2  2020-03-12T14:59:03.000Z  {'USD': {'price': 0.165223525359, 'volume_24h'...
# 3  2020-03-12T14:59:23.000Z  {'USD': {'price': 1.00339679251, 'volume_24h':...
# 4  2020-03-12T14:59:06.000Z  {'USD': {'price': 180.953362941, 'volume_24h':...

# %% [markdown]
# ## API Mercado Livre

# %%
import sys
import json
import codecs
import urllib.request
import urllib.parse

def usage():
    print('Uso: {0} "PRODUTO"'.format(sys.argv[0]))
    print('Busque um produto por vez')
    sys.exit(1)


def busca(item):
    url = 'https://api.mercadolibre.com/sites/MLB/search?q={0}'.format(item)
    opener = urllib.request.build_opener()
    opener.addheaders = [
        ('User-agent',
         "Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201")]

    with opener.open(url) as fd:
        content = fd.read()
        encoding = fd.info().get_content_charset()
        content = content.decode(encoding)

    dic = json.loads(content)
    
    return dic

# %%
temp = busca('iphone')

# %%
temp
# Out:
# {'site_id': 'MLB',
#  'query': 'iphone',
#  'paging': {'total': 43756, 'offset': 0, 'limit': 50, 'primary_results': 1036},
#  'results': [{'id': 'MLB1377032429',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 6s 64 Gb Ouro-rosa 2 Gb Ram',
#    'seller': {'id': 494830449,
#     'permalink': None,
#     'power_seller_status': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 1350,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 50,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-11-25T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-6s-64-gb-ouro-rosa-2-gb-ram/p/MLB6127576',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/923763-MLA31347280239_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 112.5,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'value_name': 'Apple',
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_struct': None},
#     {'attribute_group_id': 'OTHERS',
#      'name': 'Modelo de CPU',
#      'value_name': '2x1.84 GHz Twister',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '6973027',
#        'name': '2x1.84 GHz Twister'}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'CPU_MODEL',
#      'value_id': '6973027'},
#     {'source': 4709228965570453,
#      'id': 'GPU_MODEL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '8094621',
#        'name': 'PowerVR GT7600',
#        'struct': None,
#        'source': 4709228965570453}],
#      'name': 'Modelo de GPU',
#      'value_id': '8094621',
#      'value_name': 'PowerVR GT7600'},
#     {'name': 'Condição do item',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3570163010178927}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 3570163010178927,
#      'id': 'ITEM_CONDITION',
#      'value_id': '2230284'},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'value_name': 'iPhone',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'MODEL',
#      'value_name': 'iPhone 6s',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_id': '312151',
#      'values': [{'id': '312151',
#        'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'id': 'PROCESSOR_MODEL',
#      'value_id': '6973026',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}]}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB6127576',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1466332510',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 8 Plus 64 Gb Ouro 3 Gb Ram',
#    'seller': {'id': 234000251,
#     'permalink': None,
#     'power_seller_status': 'platinum',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 3183.05,
#    'currency_id': 'BRL',
#    'available_quantity': 500,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-03-07T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-8-plus-64-gb-ouro-3-gb-ram/p/MLB8752451',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/608954-MLA40244990046_122019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 304.22,
#     'rate': 14.69,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'BRAND',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'value_id': '9344'},
#     {'name': 'Modelo de CPU',
#      'value_id': '7058223',
#      'value_name': '2x2.4 GHz Monsoon/4x1.6 GHz Mistral',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'CPU_MODEL',
#      'values': [{'source': 1,
#        'id': '7058223',
#        'name': '2x2.4 GHz Monsoon/4x1.6 GHz Mistral',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'values': [{'struct': None,
#        'source': 1,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item'},
#     {'value_id': '58993',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_name': 'iPhone',
#      'value_struct': None},
#     {'name': 'Modelo',
#      'value_id': '2244673',
#      'attribute_group_id': 'OTHERS',
#      'id': 'MODEL',
#      'value_name': 'iPhone 8 Plus',
#      'value_struct': None,
#      'values': [{'id': '2244673',
#        'name': 'iPhone 8 Plus',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_struct': None,
#      'values': [{'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 1,
#        'id': '6936434'}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '6936434',
#      'value_name': 'Apple A11 Bionic',
#      'attribute_group_id': 'OTHERS'}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'catalog_product_id': 'MLB8752451',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1382759520',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 7 128 Gb Preto-fosco 2 Gb Ram',
#    'seller': {'id': 294154679,
#     'permalink': None,
#     'power_seller_status': 'gold',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 2240,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 25,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-12-01T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-7-128-gb-preto-fosco-2-gb-ram/p/MLB6240121',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/626644-MLA31347581774_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 186.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-PR',
#     'state_name': 'Paraná',
#     'city_id': 'TUxCQ1NBTzUyMjZl',
#     'city_name': 'São José dos Pinhais'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-PR', 'name': 'Paraná'},
#     'city': {'id': 'TUxCQ1NBTzUyMjZl', 'name': 'São José dos Pinhais'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_struct': None,
#      'values': [{'source': 1, 'id': '9344', 'name': 'Apple', 'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'value_name': 'Apple',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344'},
#     {'value_id': '6946001',
#      'value_name': '2x2.34 GHz Hurricane/2x2.34 GHz Zephyr',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'CPU_MODEL',
#      'name': 'Modelo de CPU',
#      'value_struct': None,
#      'values': [{'id': '6946001',
#        'name': '2x2.34 GHz Hurricane/2x2.34 GHz Zephyr',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'values': [{'source': 4709228965570453,
#        'id': '8010379',
#        'name': 'PowerVR Series7XT Plus',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'value_id': '8010379',
#      'value_name': 'PowerVR Series7XT Plus',
#      'value_struct': None,
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1572}],
#      'attribute_group_name': 'Outros',
#      'source': 1572},
#     {'value_id': '58993',
#      'value_struct': None,
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE'},
#     {'value_name': 'iPhone 7',
#      'values': [{'id': '312155',
#        'name': 'iPhone 7',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '312155',
#      'value_struct': None},
#     {'value_name': 'Apple A10 Fusion',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '6946002',
#      'values': [{'name': 'Apple A10 Fusion',
#        'struct': None,
#        'source': 1,
#        'id': '6946002'}]}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB6240121',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'brand_verified',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1362170369',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone Xr Dual Sim 64 Gb Preto 3 Gb Ram',
#    'seller': {'id': 147172848,
#     'permalink': None,
#     'power_seller_status': 'platinum',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 3599,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 5,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-11-05T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-xr-dual-sim-64-gb-preto-3-gb-ram/p/MLB12866681',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/811154-MLA31348359740_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 299.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_name': 'Apple',
#      'attribute_group_name': 'Outros',
#      'value_id': '9344',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'CPU_MODEL',
#      'name': 'Modelo de CPU',
#      'value_id': '6927770',
#      'value_name': '2x2.5 GHz Vortex/4x1.6 GHz Tempest',
#      'attribute_group_id': 'OTHERS',
#      'value_struct': None,
#      'values': [{'id': '6927770',
#        'name': '2x2.5 GHz Vortex/4x1.6 GHz Tempest',
#        'struct': None,
#        'source': 1}]},
#     {'source': 3570163010178927,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3570163010178927}],
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'id': 'LINE',
#      'value_id': '58993',
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'name': 'Modelo',
#      'value_id': '5414260',
#      'values': [{'id': '5414260',
#        'name': 'iPhone XR',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'MODEL',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_name': 'iPhone XR'},
#     {'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_name': 'Apple A12 Bionic',
#      'values': [{'source': 1,
#        'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None}],
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '6927771'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB12866681',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1374789608',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 7 32 Gb Ouro-rosa 2 Gb Ram',
#    'seller': {'id': 147172848,
#     'permalink': None,
#     'power_seller_status': 'platinum',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 2099,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 1,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2039-11-22T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-7-32-gb-ouro-rosa-2-gb-ram/p/MLB6240113',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/840867-MLA31347859508_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 200.61,
#     'rate': 14.69,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 1}],
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple'},
#     {'name': 'Modelo de CPU',
#      'value_name': '2x2.34 GHz Hurricane/2x2.34 GHz Zephyr',
#      'value_struct': None,
#      'values': [{'id': '6946001',
#        'name': '2x2.34 GHz Hurricane/2x2.34 GHz Zephyr',
#        'struct': None,
#        'source': 1}],
#      'id': 'CPU_MODEL',
#      'value_id': '6946001',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'name': 'Modelo de GPU',
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'value_struct': None,
#      'values': [{'id': '8010379',
#        'name': 'PowerVR Series7XT Plus',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'GPU_MODEL',
#      'value_id': '8010379',
#      'value_name': 'PowerVR Series7XT Plus'},
#     {'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 8342579661593500,
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 8342579661593500}],
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'LINE',
#      'value_id': '58993',
#      'value_struct': None,
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'attribute_group_id': 'OTHERS',
#      'name': 'Modelo',
#      'value_id': '312155',
#      'value_name': 'iPhone 7',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'MODEL',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '312155',
#        'name': 'iPhone 7',
#        'struct': None}]},
#     {'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '6946002',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A10 Fusion',
#      'values': [{'id': '6946002',
#        'name': 'Apple A10 Fusion',
#        'struct': None,
#        'source': 1}]}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB6240113',
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'extended_warranty_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1345522738',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 8 64 Gb Cinza-espacial 2 Gb Ram',
#    'seller': {'id': 234000251,
#     'permalink': None,
#     'power_seller_status': 'platinum',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 2701.01,
#    'currency_id': 'BRL',
#    'available_quantity': 500,
#    'sold_quantity': 200,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-10-15T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-8-64-gb-cinza-espacial-2-gb-ram/p/MLB8752432',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/985016-MLA31348436589_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 225.08,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'value_name': 'Apple',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'id': 'CPU_MODEL',
#      'value_name': '2x2.4 GHz Monsoon/4x1.6 GHz Mistral',
#      'values': [{'id': '7058223',
#        'name': '2x2.4 GHz Monsoon/4x1.6 GHz Mistral',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo de CPU',
#      'value_id': '7058223'},
#     {'value_struct': None,
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 4861189438295807,
#        'id': '2230284'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 4861189438295807,
#      'value_id': '2230284',
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION'},
#     {'value_name': 'iPhone',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '58993',
#      'name': 'Linha',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'id': 'LINE'},
#     {'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'MODEL',
#      'value_id': '2244670',
#      'value_name': 'iPhone 8',
#      'values': [{'id': '2244670',
#        'name': 'iPhone 8',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo',
#      'value_struct': None},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'value_id': '6936434',
#      'value_name': 'Apple A11 Bionic',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '6936434',
#        'name': 'Apple A11 Bionic'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'catalog_product_id': 'MLB8752432',
#    'tags': ['good_quality_thumbnail',
#     'brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1419061414',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone Xr - Branco - 128 Gb - 3 Gb',
#    'seller': {'id': 329917454,
#     'permalink': None,
#     'power_seller_status': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 3167,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-01-23T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-xr-branco-128-gb-3-gb/p/MLB12866684',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/669800-MLA31348461145_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 263.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BJdG9iaQ',
#     'city_name': 'Itobi'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BJdG9iaQ', 'name': 'Itobi'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'value_id': '9344',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'name': 'Marca',
#      'value_name': 'Apple',
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'CPU_MODEL',
#      'name': 'Modelo de CPU',
#      'value_name': '2x2.5 GHz Vortex/4x1.6 GHz Tempest',
#      'attribute_group_id': 'OTHERS',
#      'value_id': '6927770',
#      'value_struct': None,
#      'values': [{'id': '6927770',
#        'name': '2x2.5 GHz Vortex/4x1.6 GHz Tempest',
#        'struct': None,
#        'source': 1}]},
#     {'name': 'Condição do item',
#      'value_name': 'Novo',
#      'values': [{'source': 6808261514773724,
#        'id': '2230284',
#        'name': 'Novo',
#        'struct': None}],
#      'id': 'ITEM_CONDITION',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 6808261514773724,
#      'value_id': '2230284'},
#     {'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '58993',
#        'name': 'iPhone'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'value_struct': None,
#      'values': [{'id': '5414260',
#        'name': 'iPhone XR',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '5414260',
#      'name': 'Modelo',
#      'value_name': 'iPhone XR',
#      'id': 'MODEL'},
#     {'value_name': 'Apple A12 Bionic',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '6927771',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'name': 'Modelo do processador',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '6927771',
#        'name': 'Apple A12 Bionic'}]}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB12866684',
#    'tags': ['good_quality_thumbnail',
#     'brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1366577023',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 7 Plus 128 Gb Preto-fosco 3 Gb Ram',
#    'seller': {'id': 51968353,
#     'permalink': None,
#     'power_seller_status': 'platinum',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 3240,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 25,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-11-12T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-7-plus-128-gb-preto-fosco-3-gb-ram/p/MLB6240137',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/655402-MLA40678444606_022020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 270,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'source': 1},
#     {'value_name': '2x2.34 GHz Hurricane/2x2.34 GHz Zephyr',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '6946001',
#        'name': '2x2.34 GHz Hurricane/2x2.34 GHz Zephyr'}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'CPU_MODEL',
#      'value_id': '6946001',
#      'source': 1,
#      'name': 'Modelo de CPU',
#      'attribute_group_name': 'Outros'},
#     {'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_id': '8010379',
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'value_name': 'PowerVR Series7XT Plus',
#      'value_struct': None,
#      'values': [{'id': '8010379',
#        'name': 'PowerVR Series7XT Plus',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_id': 'OTHERS'},
#     {'attribute_group_id': 'OTHERS',
#      'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'attribute_group_name': 'Outros',
#      'source': 6808261514773724,
#      'name': 'Condição do item'},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'LINE',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'id': '312157',
#        'name': 'iPhone 7 Plus',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'MODEL',
#      'value_id': '312157',
#      'value_name': 'iPhone 7 Plus',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A10 Fusion',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '6946002',
#        'name': 'Apple A10 Fusion',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '6946002',
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB6240137',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'brand_verified',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1455561721',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 11 Dual Sim 64 Gb Preto 4 Gb Ram',
#    'seller': {'id': 6310926,
#     'permalink': None,
#     'power_seller_status': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 4329.9,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-02-27T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-11-dual-sim-64-gb-preto-4-gb-ram/p/MLB15149561',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/885508-MLA32445302787_102019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 360.83,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-29',
#     'city_name': 'Sorocaba'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-29', 'name': 'Sorocaba'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_name': 'Outros'},
#     {'id': 'CPU_MODEL',
#      'name': 'Modelo de CPU',
#      'value_id': '7740541',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_name': '2x2.65 GHz Lightning/4x1.8 GHz Thunder',
#      'values': [{'id': '7740541',
#        'name': '2x2.65 GHz Lightning/4x1.8 GHz Thunder',
#        'struct': None,
#        'source': 1}]},
#     {'values': [{'id': '7740544',
#        'name': 'Apple GPU MP4',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_name': 'Apple GPU MP4',
#      'value_struct': None,
#      'value_id': '7740544',
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU'},
#     {'source': 3570163010178927,
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'source': 3570163010178927,
#        'id': '2230284',
#        'name': 'Novo',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS'},
#     {'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}]},
#     {'attribute_group_id': 'OTHERS',
#      'name': 'Modelo',
#      'value_id': '7739079',
#      'value_name': 'iPhone 11',
#      'value_struct': None,
#      'id': 'MODEL',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '7739079',
#        'name': 'iPhone 11'}],
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'values': [{'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1,
#        'id': '7740540'}],
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB15149561',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1433144001',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone X 64 Gb Cinza-espacial 3 Gb Ram',
#    'seller': {'id': 181463963,
#     'permalink': None,
#     'power_seller_status': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 3799,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 3,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-02-06T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-x-64-gb-cinza-espacial-3-gb-ram/p/MLB7979517',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/955797-MLA31348023473_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 363.09,
#     'rate': 14.69,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'CPU_MODEL',
#      'name': 'Modelo de CPU',
#      'value_id': '6936435',
#      'value_name': '2x2.39 GHz Monsoon/4x1.6 GHz Mistral',
#      'values': [{'id': '6936435',
#        'name': '2x2.39 GHz Monsoon/4x1.6 GHz Mistral',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'attribute_group_name': 'Outros',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'values': [{'struct': None,
#        'source': 6808261514773724,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'source': 6808261514773724},
#     {'id': 'LINE',
#      'name': 'Linha',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'value_id': '1164456',
#      'value_name': 'iPhone X',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'values': [{'source': 1,
#        'id': '1164456',
#        'name': 'iPhone X',
#        'struct': None}],
#      'source': 1,
#      'id': 'MODEL'},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'values': [{'source': 1,
#        'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'value_id': '6936434',
#      'value_name': 'Apple A11 Bionic',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB7979517',
#    'tags': ['good_quality_thumbnail',
#     'brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1272167863',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 6s Plus 64 Gb Ouro-rosa 2 Gb Ram',
#    'seller': {'id': 51968353,
#     'permalink': None,
#     'power_seller_status': 'platinum',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 2288,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 100,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-07-07T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-6s-plus-64-gb-ouro-rosa-2-gb-ram/p/MLB6143815',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/962655-MLA31347321767_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 190.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'value_name': 'Apple',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'CPU_MODEL',
#      'value_id': '6973027',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo de CPU',
#      'value_name': '2x1.84 GHz Twister',
#      'values': [{'name': '2x1.84 GHz Twister',
#        'struct': None,
#        'source': 1,
#        'id': '6973027'}]},
#     {'source': 3376461333454861,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'values': [{'source': 3376461333454861,
#        'id': '2230284',
#        'name': 'Novo',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None},
#     {'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None,
#      'value_name': 'iPhone'},
#     {'id': 'MODEL',
#      'value_id': '312153',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo',
#      'value_name': 'iPhone 6s Plus',
#      'values': [{'id': '312153',
#        'name': 'iPhone 6s Plus',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'value_id': '6973026',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB6143815',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1466295212',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 6s 32 Gb Cinza-espacial 2 Gb Ram',
#    'seller': {'id': 64612936,
#     'permalink': None,
#     'power_seller_status': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 1135,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-03-07T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-6s-32-gb-cinza-espacial-2-gb-ram/p/MLB6282512',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/904184-MLA31348023096_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 108.48,
#     'rate': 14.69,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-RJ',
#     'state_name': 'Rio de Janeiro',
#     'city_id': 'BR-RJ-01',
#     'city_name': 'Rio de Janeiro'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-RJ', 'name': 'Rio de Janeiro'},
#     'city': {'id': 'BR-RJ-01', 'name': 'Rio de Janeiro'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}]},
#     {'name': 'Modelo de CPU',
#      'value_id': '6973027',
#      'value_name': '2x1.84 GHz Twister',
#      'values': [{'id': '6973027',
#        'name': '2x1.84 GHz Twister',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'CPU_MODEL',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_id': '8094621',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_name': 'PowerVR GT7600',
#      'value_struct': None,
#      'values': [{'id': '8094621',
#        'name': 'PowerVR GT7600',
#        'struct': None,
#        'source': 1}],
#      'source': 1},
#     {'values': [{'struct': None,
#        'source': 3045741222775799,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_id': 'OTHERS',
#      'value_id': '2230284',
#      'value_struct': None,
#      'value_name': 'Novo',
#      'attribute_group_name': 'Outros',
#      'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item'},
#     {'source': 1,
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'LINE',
#      'value_struct': None,
#      'attribute_group_name': 'Outros'},
#     {'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'value_id': '312151',
#      'value_name': 'iPhone 6s',
#      'values': [{'id': '312151',
#        'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1}],
#      'id': 'MODEL',
#      'name': 'Modelo'},
#     {'value_id': '6973026',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
# ...
#     'state': {'id': 'BR-RJ', 'name': 'Rio de Janeiro'},
#     'city': {'id': 'BR-RJ-01', 'name': 'Rio de Janeiro'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 6587939990796619}],
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619},
#     {'source': 6587939990796619,
#      'value_id': '6946001',
#      'value_struct': None,
#      'value_name': '2x2.34 GHz Hurricane/2x2.34 GHz Zephyr',
#      'values': [{'id': '6946001',
#        'name': '2x2.34 GHz Hurricane/2x2.34 GHz Zephyr',
#        'struct': None,
#        'source': 6587939990796619}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'CPU_MODEL',
#      'name': 'Modelo de CPU'},
#     {'value_struct': None,
#      'source': 4709228965570453,
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_id': '8010379',
#      'value_name': 'PowerVR Series7XT Plus',
#      'values': [{'struct': None,
#        'source': 4709228965570453,
#        'id': '8010379',
#        'name': 'PowerVR Series7XT Plus'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Condição do item',
#      'values': [{'name': 'Usado',
#        'struct': None,
#        'source': 1572,
#        'id': '2230581'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1572,
#      'id': 'ITEM_CONDITION',
#      'value_id': '2230581',
#      'value_name': 'Usado',
#      'value_struct': None,
#      'attribute_group_name': 'Outros'},
#     {'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'name': 'Linha',
#      'values': [{'source': 6587939990796619,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619,
#      'id': 'LINE'},
#     {'value_name': 'iPhone 7',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619,
#      'id': 'MODEL',
#      'value_id': '312155',
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo',
#      'values': [{'struct': None,
#        'source': 6587939990796619,
#        'id': '312155',
#        'name': 'iPhone 7'}]},
#     {'value_id': '6946002',
#      'value_struct': None,
#      'values': [{'id': '6946002',
#        'name': 'Apple A10 Fusion',
#        'struct': None,
#        'source': 6587939990796619}],
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A10 Fusion',
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB6240112',
#    'tags': ['dragged_bids_and_visits',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible']},
#   {'id': 'MLB1414878265',
#    'site_id': 'MLB',
#    'title': 'iPhone 7 32gb Original Vitrine Garantia Nf 12x Sem Juros ',
#    'seller': {'id': 140537020,
#     'permalink': None,
#     'power_seller_status': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': []},
#    'price': 1347,
#    'currency_id': 'BRL',
#    'available_quantity': 50,
#    'sold_quantity': 200,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-01-18T04:00:00.000Z',
#    'condition': 'used',
#    'permalink': 'https://produto.mercadolivre.com.br/MLB-1414878265-iphone-7-32gb-original-vitrine-garantia-nf-12x-sem-juros-_JM',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/899238-MLB31828092278_082019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 112.25,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-RJ',
#     'state_name': 'Rio de Janeiro',
#     'city_id': 'BR-RJ-01',
#     'city_name': 'Rio de Janeiro'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': [],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-RJ', 'name': 'Rio de Janeiro'},
#     'city': {'id': 'BR-RJ-01', 'name': 'Rio de Janeiro'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 6587939990796619}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619},
#     {'value_id': '6946001',
#      'value_struct': None,
#      'values': [{'id': '6946001',
#        'name': '2x2.34 GHz Hurricane/2x2.34 GHz Zephyr',
#        'struct': None,
#        'source': 6587939990796619}],
#      'name': 'Modelo de CPU',
#      'value_name': '2x2.34 GHz Hurricane/2x2.34 GHz Zephyr',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619,
#      'id': 'CPU_MODEL'},
#     {'values': [{'id': '8010379',
#        'name': 'PowerVR Series7XT Plus',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'value_id': '8010379',
#      'value_name': 'PowerVR Series7XT Plus',
#      'value_struct': None,
#      'name': 'Modelo de GPU',
#      'source': 4709228965570453},
#     {'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1572,
#        'id': '2230581',
#        'name': 'Usado'}],
#      'source': 1572,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230581',
#      'value_name': 'Usado',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'value_name': 'iPhone',
#      'id': 'LINE',
#      'value_id': '58993',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 6587939990796619}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619,
#      'name': 'Linha',
#      'value_struct': None},
#     {'attribute_group_id': 'OTHERS',
#      'source': 6587939990796619,
#      'id': 'MODEL',
#      'value_id': '312155',
#      'values': [{'id': '312155',
#        'name': 'iPhone 7',
#        'struct': None,
#        'source': 6587939990796619}],
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_name': 'iPhone 7',
#      'value_struct': None},
#     {'value_id': '6946002',
#      'value_name': 'Apple A10 Fusion',
#      'value_struct': None,
#      'values': [{'source': 6587939990796619,
#        'id': '6946002',
#        'name': 'Apple A10 Fusion',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 6587939990796619,
#      'name': 'Modelo do processador',
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'catalog_product_id': 'MLB6240112',
#    'tags': ['dragged_bids_and_visits',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible']}],
#  'secondary_results': [],
#  'related_results': [],
#  'sort': {'id': 'relevance', 'name': 'Mais relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor preço'},
#   {'id': 'price_desc', 'name': 'Maior preço'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorias',
#    'type': 'text',
#    'values': [{'id': 'MLB1055',
#      'name': 'Celulares e Smartphones',
#      'path_from_root': [{'id': 'MLB1051', 'name': 'Celulares e Telefones'},
#       {'id': 'MLB1055', 'name': 'Celulares e Smartphones'}]}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '9344', 'name': 'Apple'}]},
#   {'id': 'LINE',
#    'name': 'Linha',
#    'type': 'STRING',
#    'values': [{'id': '58993', 'name': 'iPhone'}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Lojas oficiais',
#    'type': 'text',
#    'values': [{'id': 'all', 'name': 'Todas as Lojas oficiais', 'results': 206},
#     {'id': '942', 'name': 'Fast Shop', 'results': 42},
#     {'id': '1553', 'name': 'Mobcom', 'results': 7},
#     {'id': '817', 'name': 'COMMCENTER', 'results': 51},
#     {'id': '2151', 'name': 'DGTec', 'results': 1}]},
#   {'id': 'state',
#    'name': 'Localização',
#    'type': 'text',
#    'values': [{'id': 'TUxCUFNBT085N2E4',
#      'name': 'São Paulo',
#      'results': 19786},
#     {'id': 'TUxCUE1JTlMxNTAyZA', 'name': 'Minas Gerais', 'results': 4215},
#     {'id': 'TUxCUFJJT08xODM5Zg', 'name': 'Rio de Janeiro', 'results': 3873},
#     {'id': 'TUxCUFBBUkExODBlZA', 'name': 'Paraná', 'results': 3047},
#     {'id': 'TUxCUFNBTkE5Nzc4', 'name': 'Santa Catarina', 'results': 1711},
#     {'id': 'TUxCUFJJT0xkYzM0', 'name': 'Rio Grande do Sul', 'results': 1564},
#     {'id': 'TUxCUEJBSEFlYmEx', 'name': 'Bahia', 'results': 1545},
#     {'id': 'TUxCUEdPSVMxNzVmMw', 'name': 'Goiás', 'results': 1470},
#     {'id': 'TUxCUERJU0wxMWJhYg', 'name': 'Distrito Federal', 'results': 1040},
#     {'id': 'TUxCUFBFUk8xZmZj', 'name': 'Pernambuco', 'results': 770},
#     {'id': 'TUxCUEVTUE8xN2Y3NA', 'name': 'Espírito Santo', 'results': 689},
#     {'id': 'TUxCUENFQUExNzkyZQ', 'name': 'Ceará', 'results': 595},
#     {'id': 'TUxCUE1BVEw4ZTc', 'name': 'Mato Grosso do Sul', 'results': 555},
#     {'id': 'TUxCUE1BVE9jZDY0', 'name': 'Mato Grosso', 'results': 320},
#     {'id': 'TUxCUFBBUkFiY2Uw', 'name': 'Pará', 'results': 320},
#     {'id': 'TUxCUE1BUk81MWVi', 'name': 'Maranhão', 'results': 305},
#     {'id': 'TUxCUFBBUkE0M2I4', 'name': 'Paraíba', 'results': 250},
#     {'id': 'TUxCUEFNQVMxNzgwYQ', 'name': 'Amazonas', 'results': 210},
#     {'id': 'TUxCUEFMQVNmZjUw', 'name': 'Alagoas', 'results': 170},
#     {'id': 'TUxCUFJJT0VkMmNj', 'name': 'Rio Grande do Norte', 'results': 170},
#     {'id': 'TUxCUFNFUkUxMmZlOQ', 'name': 'Sergipe', 'results': 170},
#     {'id': 'TUxCUFBJQUk1NDVj', 'name': 'Piauí', 'results': 155},
#     {'id': 'TUxCUFRPQ1NjZDBm', 'name': 'Tocantins', 'results': 105},
#     {'id': 'TUxCUFJPTkExMmU4YQ', 'name': 'Rondônia', 'results': 70},
#     {'id': 'TUxCUEFNQUExNTZlNg', 'name': 'Amapá', 'results': 55},
#     {'id': 'TUxCUEFDUkVkNTU', 'name': 'Acre', 'results': 45},
#     {'id': 'TUxCUFJPUkExODBiMQ', 'name': 'Roraima', 'results': 35}]},
#   {'id': 'price',
#    'name': 'Preço',
#    'type': 'range',
#    'values': [{'id': '*-1000.0', 'name': 'Até R$1.000', 'results': 12013},
#     {'id': '1000.0-2000.0', 'name': 'R$1.000 a R$2.000', 'results': 13894},
#     {'id': '2000.0-*', 'name': 'Mais de R$2.000', 'results': 17813}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com MercadoPago', 'results': 43720}]},
#   {'id': 'installments',
#    'name': 'Pagamento',
#    'type': 'text',
#    'values': [{'id': 'no_interest', 'name': 'Sem juros', 'results': 9392}]},
#   {'id': 'shipping',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envios',
#      'results': 40677},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 5}]},
#   {'id': 'power_seller',
#    'name': 'Filtro MercadoLíderes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Melhores vendedores', 'results': 848}]},
#   {'id': 'since',
#    'name': 'Filtro por data de início',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Anunciados hoje', 'results': 900}]},
#   {'id': 'until',
#    'name': 'Filtro por data do fim',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Termina hoje', 'results': 480}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicações com vídeo',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Publicações com vídeo', 'results': 872}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicação com imagens',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com fotos', 'results': 43610}]},
#   {'id': 'shipping_cost',
#    'name': 'Custo do frete',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 19967}]},
#   {'id': 'CARRIER',
#    'name': 'Operadora',
#    'type': 'STRING',
#    'values': [{'id': '298335', 'name': 'Desbloqueado', 'results': 38150},
#     {'id': '298332', 'name': 'Vivo', 'results': 465},
#     {'id': '298334', 'name': 'TIM', 'results': 420},
#     {'id': '298333', 'name': 'Claro', 'results': 395},
#     {'id': '298331', 'name': 'Oi', 'results': 195},
#     {'id': '303172', 'name': 'Nextel', 'results': 170}]},
#   {'id': 'INTERNAL_MEMORY',
#    'name': 'Memória interna',
#    'type': 'range',
#    'values': [{'id': '(*-32GB)', 'name': 'Menos de 32 GB', 'results': 8965},
#     {'id': '[32GB-64GB)', 'name': '32 a 63 GB', 'results': 9475},
#     {'id': '[64GB-128GB)', 'name': '64 a 127 GB', 'results': 13235},
#     {'id': '[128GB-256GB)', 'name': '128 a 255 GB', 'results': 6835},
#     {'id': '[256GB-*)', 'name': '256 GB o mais', 'results': 4900}]},
#   {'id': 'IS_DUAL_SIM',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'É Dual SIM', 'results': 4305}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 35630},
#     {'id': '2230284', 'name': 'Novo', 'results': 8100},
#     {'id': '2230582', 'name': 'Recondicionado', 'results': 290}]},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'type': 'STRING',
#    'values': [{'id': '312155', 'name': 'iPhone 7', 'results': 7130},
#     {'id': '312151', 'name': 'iPhone 6s', 'results': 5575},
#     {'id': '312149', 'name': 'iPhone 6', 'results': 3735},
#     {'id': '312157', 'name': 'iPhone 7 Plus', 'results': 3350},
#     {'id': '312144', 'name': 'iPhone 5s', 'results': 2825},
#     {'id': '1164456', 'name': 'iPhone X', 'results': 2645},
#     {'id': '2244670', 'name': 'iPhone 8', 'results': 2600},
#     {'id': '2244673', 'name': 'iPhone 8 Plus', 'results': 2475},
#     {'id': '312154', 'name': 'iPhone SE', 'results': 1565},
#     {'id': '5414168', 'name': 'iPhone XS Max', 'results': 1405},
#     {'id': '5414260', 'name': 'iPhone XR', 'results': 1080},
#     {'id': '5414079', 'name': 'iPhone XS', 'results': 1040},
#     {'id': '312153', 'name': 'iPhone 6s Plus', 'results': 880},
#     {'id': '312152', 'name': 'iPhone 5', 'results': 875},
#     {'id': '7739079', 'name': 'iPhone 11', 'results': 830},
#     {'id': '312150', 'name': 'iPhone 6 Plus', 'results': 820},
#     {'id': '312145', 'name': 'iPhone 4s', 'results': 720},
#     {'id': '312143', 'name': 'iPhone 5c', 'results': 530},
#     {'id': '14608', 'name': 'iPhone', 'results': 500},
#     {'id': '14610', 'name': 'iPhone 4', 'results': 490},
#     {'id': '7741677', 'name': 'iPhone 11 Pro Max', 'results': 415},
#     {'id': '7741023', 'name': 'iPhone 11 Pro', 'results': 260},
#     {'id': '14609', 'name': 'iPhone 3GS', 'results': 145},
#     {'id': '59000', 'name': '5s', 'results': 115},
#     {'id': '5414092', 'name': 'iPhone XS Dual SIM', 'results': 100},
#     {'id': '52828', 'name': '7 Plus', 'results': 100},
#     {'id': '58054', 'name': 'XR', 'results': 85},
#     {'id': '14605', 'name': 'iPhone 3G', 'results': 70},
#     {'id': '4904058', 'name': '8 Plus', 'results': 60},
#     {'id': '27251', 'name': '7', 'results': 60},
#     {'id': '11043', 'name': '8', 'results': 45},
#     {'id': '58458', 'name': '4S', 'results': 35},
#     {'id': '31998', 'name': 'X', 'results': 35},
#     {'id': '165838', 'name': 'SE', 'results': 35},
#     {'id': '59833', 'name': '6', 'results': 25},
#     {'id': '5729', 'name': 'XS', 'results': 25},
#     {'id': '10971', 'name': '4', 'results': 15}]},
#   {'id': 'WITH_FINGERPRINT_READER',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com leitor de impressão digital',
#      'results': 32075}]}]}

# %%
for anuncio in temp['results']:
    print(anuncio['title'])
# Out:
# Apple iPhone 6s 64 Gb Ouro-rosa 2 Gb Ram
# Apple iPhone 8 Plus 64 Gb Ouro 3 Gb Ram
# Apple iPhone 7 128 Gb Preto-fosco 2 Gb Ram
# Apple iPhone Xr Dual Sim 64 Gb Preto 3 Gb Ram
# Apple iPhone 7 32 Gb Ouro-rosa 2 Gb Ram
# Apple iPhone 8 64 Gb Cinza-espacial 2 Gb Ram
# Apple iPhone Xr - Branco - 128 Gb - 3 Gb
# Apple iPhone 7 Plus 128 Gb Preto-fosco 3 Gb Ram
# Apple iPhone 11 Dual Sim 64 Gb Preto 4 Gb Ram
# Apple iPhone X 64 Gb Cinza-espacial 3 Gb Ram
# Apple iPhone 6s Plus 64 Gb Ouro-rosa 2 Gb Ram
# Apple iPhone 6s 32 Gb Cinza-espacial 2 Gb Ram
# Apple iPhone 11 Pro Dual Sim 64 Gb Cinza-espacial 4 Gb Ram
# Apple iPhone 7 Plus 32 Gb Preto-fosco 3 Gb Ram
# Apple iPhone 11 Dual Sim 128 Gb Preto 4 Gb Ram
# Apple iPhone 6s Plus 128 Gb Ouro-rosa 2 Gb Ram
# Apple iPhone X 256 Gb Cinza-espacial 3 Gb Ram
# Apple iPhone 11 Pro Max Dual Sim 64 Gb Cinza-espacial 4 Gb Ram
# Apple iPhone 11 Pro Max Dual Sim 256 Gb Verde-meia-noite 4 Gb Ram
# Apple iPhone Xs Max Dual Sim 64 Gb Ouro 4 Gb Ram
# Apple iPhone 11 Dual Sim 256 Gb Preto 4 Gb Ram
# Apple iPhone Se 32 Gb Cinza-espacial 2 Gb Ram
# Apple iPhone 11 Pro Dual Sim 256 Gb Verde-meia-noite 4 Gb Ram
# Apple iPhone 8 256 Gb Ouro 2 Gb Ram
# Apple iPhone Xs Max Dual Sim 256 Gb Ouro 4 Gb Ram
# Apple iPhone Xs 64 Gb Cinza-espacial 4 Gb Ram
# Apple iPhone 8 Plus 256 Gb Prata 3 Gb Ram
# Apple iPhone 6s 16 Gb Prata 2 Gb Ram
# Apple iPhone 11 Pro Max Dual Sim 512 Gb Ouro 4 Gb Ram
# Apple iPhone 8 Plus 128 Gb Cinza-espacial 3 Gb Ram
# Apple iPhone Xs Max Dual Sim 512 Gb Cinza-espacial 4 Gb Ram
# Apple iPhone Xs 256 Gb Prata 4 Gb Ram
# Apple iPhone 6s Plus 32 Gb Cinza-espacial 2 Gb Ram
# Apple iPhone 6 32 Gb Cinza-espacial 1 Gb Ram
# Apple iPhone 11 Pro Dual Sim 512 Gb Prata 4 Gb Ram
# Apple iPhone 6s - Ouro - 128 Gb - 2 Gb
# iPhone Xr Branco Tela 6,1, 128 Gb E Câmera 12mp - Mryd2br/a
# iPhone Xr Preto,tela 6,1, 64 Gb, Câmera De 12 Mp - Mry42br/a
# iPhone 6s Vitrine 64gb Original Apple Garantia 12x Sem Juros
#  iPhone 8 Plus Vitrine 64gb Original Apple Em  12x Sem Juros
# iPhone 7 32gb Vitrine
#  iPhone 8 Vitrine 64gb Original Apple Exposição 12x S/ Juros
# Apple iPhone 7 Plus 128gb Original Vitrine  Pronta-entrega
# Apple iPhone 8 Plus 64gb Original Vitrine Desbloqueado 12x
# iPhone 8 Cinza Espacial 4,7 , 4g, 64gb, 12 Mp - Mq6g2br/a
# Apple iPhone 6s Vitrine Original 64gb Garantia Promo À Vista
#  iPhone 6s Plus 64gb Lacrado Original+nota Fiscal +brindes
# iPhone 8 Plus Dourado Tela 5,5 4g 64 Gb 12 Mp Mq8n2br/a
# iPhone 7 128gb Original Vitrine Garantia Nf Brinde 12x S/ju
# iPhone 7 32gb Original Vitrine Garantia Nf 12x Sem Juros

# %%
pd.DataFrame(temp['results'])
# Out:
#                id site_id                                              title  \
# 0   MLB1377032429     MLB           Apple iPhone 6s 64 Gb Ouro-rosa 2 Gb Ram
# 1   MLB1466332510     MLB            Apple iPhone 8 Plus 64 Gb Ouro 3 Gb Ram
# 2   MLB1382759520     MLB         Apple iPhone 7 128 Gb Preto-fosco 2 Gb Ram
# 3   MLB1362170369     MLB      Apple iPhone Xr Dual Sim 64 Gb Preto 3 Gb Ram
# 4   MLB1374789608     MLB            Apple iPhone 7 32 Gb Ouro-rosa 2 Gb Ram
# ..            ...     ...                                                ...
# 45  MLB1112940983     MLB  Apple iPhone 6s Vitrine Original 64gb Garantia...
# 46  MLB1273348447     MLB   iPhone 6s Plus 64gb Lacrado Original+nota Fis...
# 47  MLB1231034995     MLB  iPhone 8 Plus Dourado Tela 5,5 4g 64 Gb 12 Mp ...
# 48  MLB1356907929     MLB  iPhone 7 128gb Original Vitrine Garantia Nf Br...
# 49  MLB1414878265     MLB  iPhone 7 32gb Original Vitrine Garantia Nf 12x...
#
#                                                seller    price currency_id  \
# 0   {'id': 494830449, 'permalink': None, 'power_se...  1350.00         BRL
# 1   {'id': 234000251, 'permalink': None, 'power_se...  3183.05         BRL
# 2   {'id': 294154679, 'permalink': None, 'power_se...  2240.00         BRL
# 3   {'id': 147172848, 'permalink': None, 'power_se...  3599.00         BRL
# 4   {'id': 147172848, 'permalink': None, 'power_se...  2099.00         BRL
# ..                                                ...      ...         ...
# 45  {'id': 145301132, 'permalink': None, 'power_se...  1299.00         BRL
# 46  {'id': 51968353, 'permalink': None, 'power_sel...  2288.00         BRL
# 47  {'id': 234000251, 'permalink': None, 'power_se...  3213.37         BRL
# 48  {'id': 140537020, 'permalink': None, 'power_se...  1587.87         BRL
# 49  {'id': 140537020, 'permalink': None, 'power_se...  1347.00         BRL
#
#     available_quantity  sold_quantity buying_mode listing_type_id  ...  \
# 0                    1             50  buy_it_now        gold_pro  ...
# 1                  500              0  buy_it_now    gold_special  ...
# 2                    1             25  buy_it_now        gold_pro  ...
# 3                    1              5  buy_it_now        gold_pro  ...
# 4                    1              1  buy_it_now    gold_special  ...
# ..                 ...            ...         ...             ...  ...
# 45                   1            250  buy_it_now    gold_special  ...
# 46                   1            100  buy_it_now        gold_pro  ...
# 47                 500            250  buy_it_now        gold_pro  ...
# 48                   1            100  buy_it_now        gold_pro  ...
# 49                  50            200  buy_it_now        gold_pro  ...
#
#                                              shipping  \
# 0   {'free_shipping': True, 'mode': 'me2', 'tags':...
# 1   {'free_shipping': False, 'mode': 'me1', 'tags'...
# 2   {'free_shipping': True, 'mode': 'me2', 'tags':...
# 3   {'free_shipping': True, 'mode': 'me2', 'tags':...
# 4   {'free_shipping': True, 'mode': 'me2', 'tags':...
# ..                                                ...
# 45  {'free_shipping': True, 'mode': 'me2', 'tags':...
# 46  {'free_shipping': True, 'mode': 'me2', 'tags':...
# 47  {'free_shipping': False, 'mode': 'me1', 'tags'...
# 48  {'free_shipping': True, 'mode': 'me2', 'tags':...
# 49  {'free_shipping': True, 'mode': 'me2', 'tags':...
#
#                                        seller_address  \
# 0   {'id': '', 'comment': '', 'address_line': '', ...
# 1   {'id': '', 'comment': '', 'address_line': '', ...
# 2   {'id': '', 'comment': '', 'address_line': '', ...
# 3   {'id': '', 'comment': '', 'address_line': '', ...
# 4   {'id': '', 'comment': '', 'address_line': '', ...
# ..                                                ...
# 45  {'id': '', 'comment': '', 'address_line': '', ...
# 46  {'id': '', 'comment': '', 'address_line': '', ...
# 47  {'id': '', 'comment': '', 'address_line': '', ...
# 48  {'id': '', 'comment': '', 'address_line': '', ...
# 49  {'id': '', 'comment': '', 'address_line': '', ...
#
#                                            attributes differential_pricing  \
# 0   [{'attribute_group_id': 'OTHERS', 'attribute_g...     {'id': 33580182}
# 1   [{'name': 'Marca', 'values': [{'name': 'Apple'...                  NaN
# 2   [{'attribute_group_name': 'Outros', 'source': ...     {'id': 33580182}
# 3   [{'id': 'BRAND', 'name': 'Marca', 'value_name'...     {'id': 33580182}
# 4   [{'values': [{'id': '9344', 'name': 'Apple', '...                  NaN
# ..                                                ...                  ...
# 45  [{'values': [{'id': '9344', 'name': 'Apple', '...                  NaN
# 46  [{'value_struct': None, 'attribute_group_id': ...     {'id': 33580182}
# 47  [{'value_struct': None, 'values': [{'id': '934...     {'id': 33580182}
# 48  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...     {'id': 33580182}
# 49  [{'name': 'Marca', 'value_id': '9344', 'value_...     {'id': 33580182}
#
#     original_price category_id official_store_id catalog_product_id  \
# 0             None     MLB1055               NaN         MLB6127576
# 1             None     MLB1055             942.0         MLB8752451
# 2             None     MLB1055               NaN         MLB6240121
# 3             None     MLB1055               NaN        MLB12866681
# 4             None     MLB1055               NaN         MLB6240113
# ..             ...         ...               ...                ...
# 45            None     MLB1055               NaN         MLB6127568
# 46            None     MLB1055               NaN         MLB6143807
# 47            None     MLB1055             942.0         MLB8752451
# 48            None     MLB1055               NaN         MLB6240112
# 49            None     MLB1055               NaN         MLB6240112
#
#                                                  tags catalog_listing
# 0   [brand_verified, extended_warranty_eligible, g...            True
# 1   [brand_verified, extended_warranty_eligible, g...            True
# 2   [extended_warranty_eligible, good_quality_pict...            True
# 3   [extended_warranty_eligible, good_quality_pict...            True
# 4   [good_quality_picture, good_quality_thumbnail,...            True
# ..                                                ...             ...
# 45  [brand_verified, extended_warranty_eligible, g...             NaN
# 46  [brand_verified, extended_warranty_eligible, g...             NaN
# 47  [brand_verified, extended_warranty_eligible, g...             NaN
# 48  [dragged_bids_and_visits, good_quality_picture...             NaN
# 49  [dragged_bids_and_visits, good_quality_picture...             NaN
#
# [50 rows x 27 columns]

# %% [markdown]
# ## NASA

# %%
url_demo ='https://api.nasa.gov/planetary/apod?api_key=AwSaMgfvaJJiSX2nO6nNzSqKP0UPfw4PgWUIxJk8'

# %%
api = requests.get(url_demo)
json = api.json()
json
# Out:
# {'copyright': 'John Kraus',
#  'date': '2020-03-12',
#  'explanation': "Short star trails appear in this single 84 second long exposure, taken on March 6 from a rotating planet. The remarkable scene also captures the flight of a Falcon 9 rocket and Dragon cargo spacecraft over Cape Canaveral Air Force Station shortly after launch, on a resupply mission bound for the International Space Station. Beginning its return to a landing zone about 9 kilometers from the launch site, the Falcon 9 first stage boostback burn arcs toward the top of the frame. The second stage continues toward low Earth orbit though, its own fiery arc traced below the first stage boostback burn from the camera's perspective, along with expanding exhaust plumes from the two stages. This Dragon spacecraft was a veteran of two previous resupply missions. Successfully returning to the landing zone, this Falcon 9 first stage had flown before too. Its second landing marked the 50th landing of a SpaceX orbital class rocket booster.",
#  'hdurl': 'https://apod.nasa.gov/apod/image/2003/crs20_boostback.jpg',
#  'media_type': 'image',
#  'service_version': 'v1',
#  'title': 'Falcon 9 Boostback',
#  'url': 'https://apod.nasa.gov/apod/image/2003/crs20_boostback1024.jpg'}

# %% [markdown]
# # Referências

# %%
# https://www.dataquest.io/blog/python-api-tutorial/
# https://medium.com/quick-code/absolute-beginners-guide-to-slaying-apis-using-python-7b380dc82236
